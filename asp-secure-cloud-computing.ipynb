# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/asp-secure-cloud-computing/blob/main/README.md) >
#
# ## CompTIA CASP+
# ###### Topic: ``Secure Cloud Computing``
# ***

# %% [markdown]
# Course material for the ``CompTIA CASP+`` certification.

# %% [markdown]
# Cloud computing is widely used by individuals and enterprises to outsource IT solutions.
#
# Cover how to identify cloud deployment and service models.
#
# Next, review cloud service level agreements, cloud security solutions, and how to work with cloud VNets.
#
# Moving on, cover how to configure cloud autoscaling to increase application availability.
#
# Also explore now to deploy a cloud-based firewall, configure firewall routing, and enable RDP through cloud firewalls.
#
# Lastly, cover learn how to create a cloud key vault and enable cloud storage security.

# %% [markdown]
# > Objectives
#
# - describe the characteristics of cloud computing
#
#
# - identify common cloud deployment models
#
#
# - identify common cloud service models
#
#
# - determine if IT uptime requirements are met by SLAs
#
#
# - classify standard cloud security mechanisms
#
#
# - download and view cloud STAR details
#
#
# - deploy a cloud virtual network
#
#
# - configure a network security group in Azure
#
#
# - deploy a Windows virtual machine in Microsoft Azure
#
#
# - deploy a Linux virtual machine in Microsoft Azure
#
#
# - peer cloud virtual networks together to facilitate connectivity
#
#
# - limit outbound network access using Azure Firewall
#
#
# - route traffic leaving the cloud to a firewall appliance
#
#
# - configure an Azure Firewall DNAT rule
#
#
# - enable cloud autoscaling to improve application performance and availability
#
#
# - create a centralized cloud key vault for secrets storage
#
#
# - configure various security settings for cloud storage

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Cloud Computing](#A) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Cloud Deployment Models](#B) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Cloud Service Models](#C) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Reviewing Cloud Service Level Agreements](#D) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Cloud Network Security](#E) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Viewing CSA STAR Data](#F) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Configuring Cloud VNets](#G) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Limiting Network Traffic with a Network Security Group](#H) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Deploying a Windows Virtual Machine in the Cloud](#I) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Deploying a Linux Virtual Machine in the Cloud](#J) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Peering Cloud VNets](#K) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Deploying a Cloud-based Firewall](#L) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Configuring Cloud-based Firewall Routing](#M) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Enabling RDP through Cloud Firewalls](#N) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Configuring Cloud Autoscaling](#O) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Deploying a Cloud Key Vault](#P) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ### [Enabling Cloud Storage Security](#Q) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="A"></a>
# ***
# ### Cloud Computing
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="B"></a>
# ***
# ### Cloud Deployment Models
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="C"></a>
# ***
# ### Cloud Service Models
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="D"></a>
# ***
# ### Reviewing Cloud Service Level Agreements
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="E"></a>
# ***
# ### Cloud Network Security
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="F"></a>
# ***
# ### Viewing CSA STAR Data
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="G"></a>
# ***
# ### Configuring Cloud VNets
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="H"></a>
# ***
# ### Limiting Network Traffic with a Network Security Group
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="I"></a>
# ***
# ### Deploying a Windows Virtual Machine in the Cloud
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="J"></a>
# ***
# ### Deploying a Linux Virtual Machine in the Cloud
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="K"></a>
# ***
# ### Peering Cloud VNets
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="L"></a>
# ***
# ### Deploying a Cloud-based Firewall
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="M"></a>
# ***
# ### Configuring Cloud-based Firewall Routing
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="N"></a>
# ***
# ### Enabling RDP through Cloud Firewalls
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="O"></a>
# ***
# ### Configuring Cloud Autoscaling
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="P"></a>
# ***
# ### Deploying a Cloud Key Vault
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="Q"></a>
# ***
# ### Enabling Cloud Storage Security
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# skillsoft, "Secure Cloud Computing," [skillsoft.com](https://web.archive.org/web/20221102151824/https://www.skillsoft.com/get-free-trial), n.d..

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
